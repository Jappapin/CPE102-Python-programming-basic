# %% [markdown]
# # Part 1: Load dataset HR-Employee-Attrition.csv

# %%
import pandas as pd
import os

df = pd.read_csv('HR-Employee-Attrition.csv', header=0, sep='\t')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# 5      32        No  Travel_Frequently       1005  Research & Development
# 6      59        No      Travel_Rarely       1324  Research & Development
# 7      30        No      Travel_Rarely       1358  Research & Development
# 8      38        No  Travel_Frequently        216  Research & Development
# 9      36        No      Travel_Rarely       1299  Research & Development
# 10     35        No      Travel_Rarely        809  Research & Development
# 11     29        No      Travel_Rarely        153  Research & Development
# ...

# %% [markdown]
# # How many record in this dataset?
#
# # How many columns and what are they?

# %%
print("There are",df.shape[0],"row(indexes).\nThere are",df.shape[1],"columns.\nThe columns are : ",df.columns,".")
# Out:
# There are 1470 row(indexes).
# There are 35 columns.
# The columns are :  Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object') .

# %% [markdown]
# # Which columns are category type?
#
# Plese be careful that some numeric type column may be categorical

# %%
df.select_dtypes(include='object')
# Out:
#      Attrition     BusinessTravel              Department    EducationField  \
# 0          Yes      Travel_Rarely                   Sales     Life Sciences
# 1           No  Travel_Frequently  Research & Development     Life Sciences
# 2          Yes      Travel_Rarely  Research & Development             Other
# 3           No  Travel_Frequently  Research & Development     Life Sciences
# 4           No      Travel_Rarely  Research & Development           Medical
# 5           No  Travel_Frequently  Research & Development     Life Sciences
# 6           No      Travel_Rarely  Research & Development           Medical
# 7           No      Travel_Rarely  Research & Development     Life Sciences
# 8           No  Travel_Frequently  Research & Development     Life Sciences
# 9           No      Travel_Rarely  Research & Development           Medical
# 10          No      Travel_Rarely  Research & Development           Medical
# ...

# %% [markdown]
# # How many JobRole and what is it?

# %%
print("There are",len(df.JobRole.unique()),"JobRole(s).\nThey are",df.JobRole.unique(),".")
# Out:
# There are 9 JobRole(s).
# They are ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources'] .

# %% [markdown]
# # How many Department and what is it?

# %%
print("There are",len(df.Department.unique()),"Department(s).\nThey are",df.Department.unique(),".")
# Out:
# There are 3 Department(s).
# They are ['Sales' 'Research & Development' 'Human Resources'] .

# %% [markdown]
# # How many EducationField and what is it?

# %%
print("There are",len(df.EducationField.unique()),"EducationField(s).\nThey are",df.EducationField.unique(),".")
# Out:
# There are 6 EducationField(s).
# They are ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources'] .

# %% [markdown]
# # What is the average age of people in this company?

# %%
print("The average age of people in this company is",df.Age.mean(),".")
# Out:
# The average age of people in this company is 36.923809523809524 .

# %% [markdown]
# # How many female in this company?

# %%
print("There are",len(df[df.Gender=="Female"]),'female(s)in this company.')
# Out:
# There are 588 female(s)in this company.

# %% [markdown]
# # How many people have monthly income more than 10000?

# %%
print("There are",len(df[df.MonthlyIncome>10000]),"people have monthly income more than 10000.")
# Out:
# There are 281 people have monthly income more than 10000.

# %% [markdown]
# # How many people who travel frequently and is single?

# %%
print("There are",len(df[(df.BusinessTravel=='Travel_Frequently') & (df.MaritalStatus=="Single")]),"people who travel frequently and are single.")
# Out:
# There are 96 people who travel frequently and are single.

# %% [markdown]
# # What is the average age of people group by maritial status?

# %%
print("the average age of people group by maritial status : \n",df.groupby('MaritalStatus').Age.mean())
# Out:
# the average age of people group by maritial status :
#  MaritalStatus
# Divorced    37.489297
# Married     37.757801
# Single      35.336170
# Name: Age, dtype: float64

# %% [markdown]
# # What is the median hourly rate of people group by Business Travel?

# %%
print("the median hourly rate of people group by Business Travel : \n",df.groupby('BusinessTravel').HourlyRate.median())
# Out:
# the median hourly rate of people group by Business Travel :
#  BusinessTravel
# Non-Travel           65
# Travel_Frequently    65
# Travel_Rarely        66
# Name: HourlyRate, dtype: int64

# %% [markdown]
# # What is the average hourly rate of people group by job role?

# %%
print("the average hourly rate of people group by job role : \n",df.groupby('JobRole').HourlyRate.mean())
# Out:
# the average hourly rate of people group by job role :
#  JobRole
# Healthcare Representative    66.839695
# Human Resources              64.173077
# Laboratory Technician        66.683398
# Manager                      66.833333
# Manufacturing Director       65.006897
# Research Director            63.762500
# Research Scientist           66.708904
# Sales Executive              65.438650
# Sales Representative         64.337349
# Name: HourlyRate, dtype: float64

# %% [markdown]
# # Which job role has more hourly rate than overall average?

# %%
data_=df.groupby('JobRole').HourlyRate.mean()
result=0
for i in data_:
    if i > result:
        result=i
    f=data.where(data==result)
f.dropna(how='any')
# Out:
# JobRole
# Healthcare Representative    66.839695
# Name: HourlyRate, dtype: float64
